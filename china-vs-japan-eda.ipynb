# %% [markdown]
# <a id="2"></a>
# <div style="display: flex; align-items: center; justify-content: center; text-align:center; border-radius:20px; padding:30px; color:white; margin:0 auto; font-size:440%; font-family:Arial; background-color:green; overflow:hidden; width: 500px; height: 200px;
#     box-shadow: 0 0 000px 00px rgba(5.03, 5.00, 5, 5.0);">
#     <b>CHINA VS JAPAN COMPARISON</b>
# </div>

# %% [markdown]
# <a id="2"></a>
# # <div style="text-align:center; border-radius:15px 50px; padding:15px; color:white; margin:0; font-size:100%; font-family:Arial; background-color:green; overflow:hidden"><b>  ✨ **About Author** ✨ </b></div>
#
# <div style="background-color: white; border: 9px solid green; border-radius: 19px; box-shadow: 0 10px 20px rgba(0, 0, 0, 0.1); max-width: 600px; margin: 20px auto; padding: 20px; text-align: center; font-family: 'Segoe UI', Tahoma, Geneva, Verdana, sans-serif;">
#     <h2 style="color: black; font-weight: bold; margin-bottom: 10px;">WAQAR ALI</h2>
#     <p style="font-size: 16px; line-height: 1.6; color: black; margin-bottom: 20px;">
#         I'm a passionate Data Scientist and Analyst, dedicated to transforming raw data into actionable insights through captivating visualizations. Let's dive into the fascinating world of data and uncover the stories hidden within! 📊🔍✨
#     </p>
#     <p style="color: black; font-size: 16px; font-weight: bold;">Connect with me:</p>
#     <a href="https://www.linkedin.com/in/waqar-ali-a51297318/" target="_blank" style="display: inline-block; background-color: purple; color: white; text-decoration: none; padding: 10px 20px; border-radius: 5px; margin: 5px;">LinkedIn</a>
#     <a href="https://github.com/waqi786" target="_blank" style="display: inline-block; background-color: green; color: white; text-decoration: none; padding: 10px 20px; border-radius: 5px; margin: 5px;">GitHub</a>
#     <a href="https://www.kaggle.com/waqi786" target="_blank" style="display: inline-block; background-color: red; color: white; text-decoration: none; padding: 10px 20px; border-radius: 5px; margin: 5px;">Kaggle</a>
#     <a href="mailto:dsali20838@gmail.com" style="display: inline-block; background-color: blue; color: white; text-decoration: none; padding: 10px 20px; border-radius: 5px; margin: 5px;">Email</a>
# </div>

# %% [markdown]
# <a id="2"></a>
# # <div style="text-align:center; border-radius:15px 50px; padding:15px; color:white; margin:0; font-size:100%; font-family:Arial; background-color:green; overflow:hidden"><b> ✨ Importing Required Libraries ✨</b></div>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import numpy as np
import warnings

# To display visuals within the notebook
# %matplotlib inline
warnings.filterwarnings('ignore')

# %% [markdown]
# <a id="2"></a>
# # <div style="text-align:center; border-radius:15px 50px; padding:15px; color:white; margin:0; font-size:100%; font-family:Arial; background-color:green; overflow:hidden"><b> ✨ Load the Dataset ✨</b></div>

# %%
# Load the dataset from the provided file path
file_path = '/kaggle/input/china-vs-japan/Big_Japan_vs_China_Technology.csv'
df = pd.read_csv(file_path)

# Display the first few rows of the dataset
df.head(10)
# Out:
#   Country  Year      Tech Sector  Market Share (%)  R&D Investment (in USD)  \
# 0   China  2001         Software         22.279014             8.377208e+10
# 1   Japan  2011    Semiconductor         31.899013             3.551134e+10
# 2   Japan  2009         Robotics         33.574466             8.480948e+10
# 3   Japan  2019  Cloud Computing         24.904248             2.267821e+10
# 4   China  2002         Robotics         46.975827             3.453655e+10
# 5   China  2022    Semiconductor         12.741990             4.029329e+10
# 6   China  2022  Cloud Computing         20.476168             4.823453e+10
# 7   China  2006         Robotics         22.585881             2.177051e+10
# 8   China  2011               AI         12.751686             1.179936e+10
# 9   Japan  2002    Biotechnology         37.217951             9.792535e+09
#
#    Number of Patents Filed (Annual)  Number of Tech Companies  \
# 0                              1415                       878
# ...

# %% [markdown]
# <a id="2"></a>
# # <div style="text-align:center; border-radius:15px 50px; padding:15px; color:white; margin:0; font-size:100%; font-family:Arial; background-color:green; overflow:hidden"><b> ✨ Basic Dataset Overview ✨</b></div>

# %%
# Get an overview of the dataset
df.info()

# Summary statistics for numerical columns
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 16 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   Country                             1000 non-null   object
#  1   Year                                1000 non-null   int64
#  2   Tech Sector                         1000 non-null   object
#  3   Market Share (%)                    1000 non-null   float64
#  4   R&D Investment (in USD)             1000 non-null   float64
#  5   Number of Patents Filed (Annual)    1000 non-null   int64
#  6   Number of Tech Companies            1000 non-null   int64
#  7   Tech Exports (in USD)               1000 non-null   float64
#  8   Number of Startups                  1000 non-null   int64
#  9   Venture Capital Funding (in USD)    1000 non-null   float64
#  10  Global Innovation Ranking           1000 non-null   int64
# ...

# %% [markdown]
# <a id="2"></a>
# # <div style="text-align:center; border-radius:15px 50px; padding:15px; color:white; margin:0; font-size:100%; font-family:Arial; background-color:green; overflow:hidden"><b> ✨ Checking for Missing Values ✨</b></div>

# %%
# Check for any missing values
missing_values = df.isnull().sum()
missing_values[missing_values > 0]  # Display columns with missing values
# Out:
# Series([], dtype: int64)

# %% [markdown]
# <a id="2"></a>
# # <div style="text-align:center; border-radius:15px 50px; padding:15px; color:white; margin:0; font-size:100%; font-family:Arial; background-color:green; overflow:hidden"><b> ✨ Handling Missing Values ✨</b></div>

# %%
# Fill missing values with median or mean based on column types
df['5G Network Coverage (%)'] = df['5G Network Coverage (%)'].fillna(df['5G Network Coverage (%)'].mean())
df['Number of Startups'] = df['Number of Startups'].fillna(df['Number of Startups'].median())

# Verify missing values have been handled
df.isnull().sum().sum()  # Should return 0 if no missing values remain
# Out:
# 0

# %% [markdown]
# <a id="2"></a>
# # <div style="text-align:center; border-radius:15px 50px; padding:15px; color:white; margin:0; font-size:100%; font-family:Arial; background-color:green; overflow:hidden"><b> ✨ Correlation Matrix ✨</b></div>

# %%
# Select only numerical columns for correlation calculation
numerical_cols = df.select_dtypes(include=['number']).columns

# Calculate correlation matrix
correlation_matrix = df[numerical_cols].corr()

# Plotting the correlation matrix
plt.figure(figsize=(12, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Correlation Matrix of Numerical Indicators')
plt.show()

# %% [markdown]
# <a id="2"></a>
# # <div style="text-align:center; border-radius:15px 50px; padding:15px; color:white; margin:0; font-size:100%; font-family:Arial; background-color:green; overflow:hidden"><b> ✨ Visualizing R&D Investment by Country ✨</b></div>

# %%
# R&D Investment Comparison
plt.figure(figsize=(10, 6))
sns.barplot(data=df, x='Country', y='R&D Investment (in USD)', palette='Set2')
plt.title('R&D Investment Comparison Between China and Japan')
plt.xlabel('Country')
plt.ylabel('R&D Investment (USD Billions)')
plt.show()

# %% [markdown]
# <a id="2"></a>
# # <div style="text-align:center; border-radius:15px 50px; padding:15px; color:white; margin:0; font-size:100%; font-family:Arial; background-color:green; overflow:hidden"><b> ✨ Number of Patents Filed Over Time ✨</b></div>

# %%
plt.figure(figsize=(12, 6))
sns.lineplot(data=df, x='Year', y='Number of Patents Filed (Annual)', hue='Country', style='Country', markers=True)
plt.title('Number of Patents Filed Over Time (China vs Japan)')
plt.xlabel('Year')
plt.ylabel('Number of Patents Filed')
plt.grid(True)
plt.show()

# %% [markdown]
# <a id="2"></a>
# # <div style="text-align:center; border-radius:15px 50px; padding:15px; color:white; margin:0; font-size:100%; font-family:Arial; background-color:green; overflow:hidden"><b> ✨ Global Innovation Ranking Over Time ✨</b></div>

# %%
plt.figure(figsize=(12, 6))
sns.lineplot(data=df, x='Year', y='Global Innovation Ranking', hue='Country', marker="o", palette='Dark2')
plt.title('Global Innovation Ranking Over Time')
plt.xlabel('Year')
plt.ylabel('Innovation Ranking (Lower is Better)')
plt.show()

# %% [markdown]
# <a id="2"></a>
# # <div style="text-align:center; border-radius:15px 50px; padding:15px; color:white; margin:0; font-size:100%; font-family:Arial; background-color:green; overflow:hidden"><b> ✨ Market Share Distribution by Tech Sector ✨</b></div>

# %%
# Group by Tech Sector and Country
sector_share = df.groupby(['Tech Sector', 'Country'])['Market Share (%)'].mean().unstack()

# Plot stacked bar chart
sector_share.plot(kind='bar', stacked=True, figsize=(10, 6), colormap='Paired')
plt.title('Market Share Distribution by Tech Sector (China vs Japan)')
plt.ylabel('Average Market Share (%)')
plt.legend(title='Country')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# <a id="2"></a>
# # <div style="text-align:center; border-radius:15px 50px; padding:15px; color:white; margin:0; font-size:100%; font-family:Arial; background-color:green; overflow:hidden"><b> ✨ Internet Penetration Over the Years ✨</b></div>

# %%
plt.figure(figsize=(12, 6))
sns.lineplot(data=df, x='Year', y='Internet Penetration (%)', hue='Country', style='Country', markers=True, dashes=False)
plt.title('Internet Penetration Over Time (China vs Japan)')
plt.xlabel('Year')
plt.ylabel('Internet Penetration (%)')
plt.grid(True)
plt.show()

# %% [markdown]
# <a id="2"></a>
# # <div style="text-align:center; border-radius:15px 50px; padding:15px; color:white; margin:0; font-size:100%; font-family:Arial; background-color:green; overflow:hidden"><b> ✨ Boxplot of Venture Capital Funding ✨</b></div>

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(data=df, x='Country', y='Venture Capital Funding (in USD)', palette='coolwarm')
plt.title('Distribution of Venture Capital Funding (China vs Japan)')
plt.xlabel('Country')
plt.ylabel('Venture Capital Funding (USD Billions)')
plt.show()

# %% [markdown]
# <a id="2"></a>
# # <div style="text-align:center; border-radius:15px 50px; padding:15px; color:white; margin:0; font-size:100%; font-family:Arial; background-color:green; overflow:hidden"><b> ✨ Scatter Plot of R&D vs. Patents Filed ✨</b></div>

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(data=df, x='R&D Investment (in USD)', y='Number of Patents Filed (Annual)', hue='Country', size='Market Share (%)', palette='muted', sizes=(40, 400))
plt.title('R&D Investment vs Patents Filed (China vs Japan)')
plt.xlabel('R&D Investment (USD Billions)')
plt.ylabel('Number of Patents Filed (Annual)')
plt.show()

# %% [markdown]
# <a id="2"></a>
# # <div style="text-align:center; border-radius:15px 50px; padding:15px; color:white; margin:0; font-size:100%; font-family:Arial; background-color:green; overflow:hidden"><b> ✨ 5G Network Coverage by Country Over Time ✨</b></div>

# %%
plt.figure(figsize=(12, 6))
sns.lineplot(data=df, x='Year', y='5G Network Coverage (%)', hue='Country', marker='o', linestyle='-', palette='Blues')
plt.title('5G Network Coverage Comparison (China vs Japan)')
plt.xlabel('Year')
plt.ylabel('5G Network Coverage (%)')
plt.show()

# %% [markdown]
# <a id="2"></a>
# # <div style="text-align:center; border-radius:15px 50px; padding:15px; color:white; margin:0; font-size:100%; font-family:Arial; background-color:green; overflow:hidden"><b> ✨ Number of Tech Workers by Country ✨</b></div>

# %%
plt.figure(figsize=(10, 6))
sns.barplot(data=df, x='Country', y='Number of Tech Workers', palette='Set3')
plt.title('Total Number of Tech Workers in China and Japan')
plt.xlabel('Country')
plt.ylabel('Number of Tech Workers')
plt.show()

# %% [markdown]
# <a id="2"></a>
# # <div style="text-align:center; border-radius:15px 50px; padding:15px; color:white; margin:0; font-size:100%; font-family:Arial; background-color:green; overflow:hidden"><b> ✨ Top Tech Products Exported by China ✨</b></div>

# %%
china_top_exports = df[df['Country'] == 'China']['Top Tech Products Exported'].value_counts().head(10)

plt.figure(figsize=(10, 6))
china_top_exports.plot(kind='bar', color='teal')
plt.title('Top Tech Products Exported by China')
plt.xlabel('Tech Products')
plt.ylabel('Frequency')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# <a id="2"></a>
# # <div style="text-align:center; border-radius:15px 50px; padding:15px; color:white; margin:0; font-size:100%; font-family:Arial; background-color:green; overflow:hidden"><b> ✨ Top Tech Products Exported by Japan ✨</b></div>

# %%
japan_top_exports = df[df['Country'] == 'Japan']['Top Tech Products Exported'].value_counts().head(10)

plt.figure(figsize=(10, 6))
japan_top_exports.plot(kind='bar', color='orange')
plt.title('Top Tech Products Exported by Japan')
plt.xlabel('Tech Products')
plt.ylabel('Frequency')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# <a id="2"></a>
# # <div style="text-align:center; border-radius:15px 50px; padding:15px; color:white; margin:0; font-size:100%; font-family:Arial; background-color:green; overflow:hidden"><b> ✨ Number of Startups in Both Countries ✨</b></div>

# %%
plt.figure(figsize=(10, 6))
sns.barplot(data=df, x='Country', y='Number of Startups', palette='Pastel1')
plt.title('Number of Startups in China and Japan')
plt.xlabel('Country')
plt.ylabel('Number of Startups')
plt.show()

# %% [markdown]
# <a id="2"></a>
# # <div style="text-align:center; border-radius:15px 50px; padding:15px; color:white; margin:0; font-size:100%; font-family:Arial; background-color:green; overflow:hidden"><b> ✨ Venture Capital Funding Over Time ✨</b></div>

# %%
plt.figure(figsize=(12, 6))
sns.lineplot(data=df, x='Year', y='Venture Capital Funding (in USD)', hue='Country', marker="o", palette='Set1')
plt.title('Venture Capital Funding Over Time (China vs Japan)')
plt.xlabel('Year')
plt.ylabel('Venture Capital Funding (USD Billions)')
plt.show()

# %% [markdown]
# <a id="2"></a>
# # <div style="text-align:center; border-radius:15px 50px; padding:15px; color:white; margin:0; font-size:100%; font-family:Arial; background-color:green; overflow:hidden"><b> ✨ University Research Collaborations Over Time ✨</b></div>

# %%
plt.figure(figsize=(12, 6))
sns.lineplot(data=df, x='Year', y='University Research Collaborations', hue='Country', marker='o', linestyle='--', palette='Dark2')
plt.title('University Research Collaborations (China vs Japan)')
plt.xlabel('Year')
plt.ylabel('Collaborations (Count)')
plt.show()

# %% [markdown]
# <a id="2"></a>
# # <div style="text-align:center; border-radius:15px 50px; padding:15px; color:white; margin:0; font-size:100%; font-family:Arial; background-color:green; overflow:hidden"><b>  Pie Chart of Market Share by Tech Sector for China </b></div>

# %%
china_market_share = df[df['Country'] == 'China'].groupby('Tech Sector')['Market Share (%)'].mean()

# Plot pie chart
plt.figure(figsize=(8, 8))
plt.pie(china_market_share, labels=china_market_share.index, autopct='%1.1f%%', startangle=90, colors=sns.color_palette('coolwarm', len(china_market_share)))
plt.title('China: Market Share by Tech Sector')
plt.show()

# %% [markdown]
# <a id="2"></a>
# # <div style="text-align:center; border-radius:15px 50px; padding:15px; color:white; margin:0; font-size:100%; font-family:Arial; background-color:green; overflow:hidden"><b>  Pie Chart of Market Share by Tech Sector for Japan </b></div>

# %%
japan_market_share = df[df['Country'] == 'Japan'].groupby('Tech Sector')['Market Share (%)'].mean()

# Plot pie chart
plt.figure(figsize=(8, 8))
plt.pie(japan_market_share, labels=japan_market_share.index, autopct='%1.1f%%', startangle=90, colors=sns.color_palette('Set3', len(japan_market_share)))
plt.title('Japan: Market Share by Tech Sector')
plt.show()

# %% [markdown]
# <a id="2"></a>
# # <div style="text-align:center; border-radius:15px 50px; padding:15px; color:white; margin:0; font-size:100%; font-family:Arial; background-color:green; overflow:hidden"><b> ✨ Distribution of Internet Penetration ✨</b></div>

# %%
plt.figure(figsize=(10, 6))
sns.histplot(data=df, x='Internet Penetration (%)', hue='Country', kde=True, palette='Set2')
plt.title('Distribution of Internet Penetration (China vs Japan)')
plt.xlabel('Internet Penetration (%)')
plt.show()

# %% [markdown]
# <a id="2"></a>
# # <div style="text-align:center; border-radius:15px 50px; padding:15px; color:white; margin:0; font-size:100%; font-family:Arial; background-color:green; overflow:hidden"><b> ✨ Summary  ✨</b></div>

# %% [markdown]
# # Summary Report: China vs. Japan
#
# ## Overview
# This analysis provides an in-depth comparison of technological advancements between China and Japan based on several metrics including R&D investment, patent filings, market share by tech sector, and more. The dataset spans multiple years and includes diverse aspects of technology and innovation.
#
# ## Key Findings
#
# ### 1. R&D Investment
# - **China** significantly outspends Japan in R&D investments. This substantial investment underpins China’s rapid advancements in technology and innovation.
# - **Japan** has a more focused R&D strategy, often leading in specific tech sectors like robotics and advanced materials.
#
# ### 2. Number of Patents Filed
# - **Japan** has a higher number of patents filed annually compared to China. This indicates Japan's strong emphasis on technological innovation and intellectual property.
# - **China** is making substantial progress in patent filings, reflecting its growing focus on research and development.
#
# ### 3. Global Innovation Ranking
# - **Japan** consistently ranks higher in global innovation indices. This reflects its strong historical performance in technology and innovation.
# - **China** is climbing the ranks rapidly, thanks to its significant investments in technology and infrastructure.
#
# ### 4. Market Share by Tech Sector
# - **China** holds a dominant market share in sectors like telecommunications and electronics, benefiting from its large-scale manufacturing capabilities.
# - **Japan** leads in high-tech sectors such as robotics and precision machinery, where it has established a niche due to advanced technology and quality.
#
# ### 5. Internet Penetration
# - **Japan** has a higher rate of internet penetration compared to China. This indicates better infrastructure and accessibility in Japan.
# - **China** is making significant strides, with increasing internet access and digital infrastructure improvements.
#
# ### 6. 5G Network Coverage
# - **China** leads in 5G network coverage, showcasing its advancements in telecommunications and rapid deployment of next-generation networks.
# - **Japan** is also progressing in 5G but has a slower rollout compared to China.
#
# ### 7. Venture Capital Funding
# - **China** receives higher venture capital funding, reflecting its vibrant startup ecosystem and investor confidence in its tech sector.
# - **Japan** has a more conservative venture capital environment but is growing steadily.
#
# ### 8. Number of Startups
# - **China** has a larger number of startups, driven by its dynamic tech ecosystem and supportive policies for entrepreneurship.
# - **Japan** has fewer startups but they are often highly specialized and innovative.
#
# ### 9. University Research Collaborations
# - **China** shows increasing collaborations with universities, highlighting its commitment to research and development through academic partnerships.
# - **Japan** maintains strong collaborations but with a focus on established research institutions and long-term partnerships.
#
# ### 10. Top Tech Products Exported
# - **China** exports a broad range of tech products including consumer electronics, telecommunications equipment, and IT hardware.
# - **Japan** is known for exporting high-value tech products such as semiconductors, robotics, and precision instruments.
#
# ### 11. Number of Tech Workers
# - **China** has a significantly larger number of tech workers, supporting its vast tech industry and rapid expansion.
# - **Japan** has a highly skilled tech workforce, but its numbers are smaller due to a more mature and focused industry.
#
# ## Visual Insights
# - **Correlation Analysis**: The correlation matrix reveals strong relationships between R&D investment and number of patents filed, underscoring the link between financial investment and innovation output.
# - **Time Trends**: Trends in R&D investment and patent filings over time show China's rapid growth and Japan's steady performance.
# - **Sectoral Distribution**: Pie charts and bar graphs illustrate the dominance of specific tech sectors in each country, providing a clear picture of market share distribution.
#
# ## Conclusion
# The analysis reveals a dynamic technological landscape where China is rapidly advancing with significant investments and broad market impact, while Japan continues to excel in innovation and specialized tech sectors. Both countries contribute uniquely to the global technology ecosystem, with China driving large-scale growth and Japan focusing on high-quality and specialized technological advancements.

# %% [markdown]
# <a id="2"></a>
# # <div style="text-align:center; border-radius:15px 50px; padding:15px; color:white; margin:0; font-size:100%; font-family:Arial; background-color:green; overflow:hidden"><b> ✨ Thank You ✨</b></div>
